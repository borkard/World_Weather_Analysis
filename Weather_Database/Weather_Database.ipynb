# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 735

# %%
# Import the requests library.
import requests

import sys
sys.path.insert(0, '../')

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1944cbc39c918c9e22ecb704ec36295c

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        print(city_weather)
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
    
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ribeira grande
# {'coord': {'lon': -28.7, 'lat': 38.5167}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 62.6, 'feels_like': 57.74, 'temp_min': 62.6, 'temp_max': 62.6, 'pressure': 1022, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 13.8, 'deg': 250}, 'clouds': {'all': 40}, 'dt': 1610745179, 'sys': {'type': 1, 'id': 6883, 'country': 'PT', 'sunrise': 1610701843, 'sunset': 1610737044}, 'timezone': -3600, 'id': 3372707, 'name': 'Ribeira Grande', 'cod': 200}
# Processing Record 2 of Set 1 | castro
# {'coord': {'lon': -50.0119, 'lat': -24.7911}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 70.29, 'feels_like': 72.59, 'temp_min': 70.29, 'temp_max': 70.29, 'pressure': 1010, 'humidity': 91, 'sea_level': 1010, 'grnd_level': 901}, 'visibility': 5964, 'wind': {'speed': 7.31, 'deg': 88}, 'clouds': {'all': 46}, 'dt': 1610745179, 'sys': {'country': 'BR', 'sunrise': 1610700262, 'sunset': 1610748858}, 'timezone': -10800, 'id': 3466704, 'name': 'Castro', 'cod': 200}
# Processing Record 3 of Set 1 | bac lieu
# {'coord': {'lon': 105.7244, 'lat': 9.285}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 72.81, 'feels_like': 73.51, 'temp_min': 72.81, 'temp_max': 72.81, 'pressure': 1009, 'humidity': 86, 'sea_level': 1009, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 10.87, 'deg': 87}, 'clouds': {'all': 13}, 'dt': 1610745180, 'sys': {'country': 'VN', 'sunrise': 1610752640, 'sunset': 1610794550}, 'timezone': 25200, 'id': 1591474, 'name': 'Bac Lieu', 'cod': 200}
# Processing Record 4 of Set 1 | avarua
# {'coord': {'lon': -159.775, 'lat': -21.2078}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 84.2, 'feels_like': 88.72, 'temp_min': 84.2, 'temp_max': 84.2, 'pressure': 1014, 'humidity': 74}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 60}, 'clouds': {'all': 41}, 'dt': 1610744956, 'sys': {'type': 1, 'id': 7271, 'country': 'CK', 'sunrise': 1610727021, 'sunset': 1610774797}, 'timezone': -36000, 'id': 4035715, 'name': 'Avarua', 'cod': 200}
# Processing Record 5 of Set 1 | tabas
# {'coord': {'lon': 56.9244, 'lat': 33.5959}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 37.4, 'feels_like': 28.36, 'temp_min': 37.4, 'temp_max': 37.4, 'pressure': 1014, 'humidity': 17}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 60}, 'clouds': {'all': 0}, 'dt': 1610745180, 'sys': {'type': 1, 'id': 7487, 'country': 'IR', 'sunrise': 1610766977, 'sunset': 1610803642}, 'timezone': 12600, 'id': 113659, 'name': 'Tabas', 'cod': 200}
# Processing Record 6 of Set 1 | port elizabeth
# {'coord': {'lon': 25.5701, 'lat': -33.918}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 71.6, 'feels_like': 62.22, 'temp_min': 71.6, 'temp_max': 71.6, 'pressure': 1004, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 24.16, 'deg': 250}, 'clouds': {'all': 40}, 'dt': 1610744944, 'sys': {'type': 1, 'id': 1973, 'country': 'ZA', 'sunrise': 1610680940, 'sunset': 1610731891}, 'timezone': 7200, 'id': 964420, 'name': 'Port Elizabeth', 'cod': 200}
# Processing Record 7 of Set 1 | santa cruz de la palma
# {'coord': {'lon': -17.7642, 'lat': 28.6835}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 59.56, 'feels_like': 53.19, 'temp_min': 54, 'temp_max': 64.4, 'pressure': 1028, 'humidity': 52}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 30, 'gust': 19.57}, 'clouds': {'all': 75}, 'dt': 1610745180, 'sys': {'type': 1, 'id': 2377, 'country': 'ES', 'sunrise': 1610697891, 'sunset': 1610735746}, 'timezone': 0, 'id': 2511180, 'name': 'Santa Cruz de La Palma', 'cod': 200}
# Processing Record 8 of Set 1 | tuatapere
# {'coord': {'lon': 167.6833, 'lat': -46.1333}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 62.53, 'feels_like': 60.08, 'temp_min': 62.53, 'temp_max': 62.53, 'pressure': 1007, 'humidity': 60, 'sea_level': 1007, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 3.76, 'deg': 358}, 'clouds': {'all': 12}, 'dt': 1610745180, 'sys': {'country': 'NZ', 'sunrise': 1610731139, 'sunset': 1610786303}, 'timezone': 46800, 'id': 2180815, 'name': 'Tuatapere', 'cod': 200}
# Processing Record 9 of Set 1 | punta arenas
# {'coord': {'lon': -70.9167, 'lat': -53.15}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 55.2, 'feels_like': 44.98, 'temp_min': 55, 'temp_max': 55.4, 'pressure': 1012, 'humidity': 76}, 'visibility': 10000, 'wind': {'speed': 17.27, 'deg': 170}, 'clouds': {'all': 0}, 'dt': 1610744934, 'sys': {'type': 1, 'id': 8487, 'country': 'CL', 'sunrise': 1610700145, 'sunset': 1610759011}, 'timezone': -10800, 'id': 3874787, 'name': 'Punta Arenas', 'cod': 200}
# Processing Record 10 of Set 1 | qaanaaq
# {'coord': {'lon': -69.3632, 'lat': 77.484}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 9.32, 'feels_like': 2.66, 'temp_min': 9.32, 'temp_max': 9.32, 'pressure': 1009, 'humidity': 92, 'sea_level': 1009, 'grnd_level': 1005}, 'visibility': 4837, 'wind': {'speed': 1.3, 'deg': 127}, 'clouds': {'all': 98}, 'dt': 1610745180, 'sys': {'country': 'GL', 'sunrise': 0, 'sunset': 0}, 'timezone': -14400, 'id': 3831208, 'name': 'Qaanaaq', 'cod': 200}
# Processing Record 11 of Set 1 | dunda
# {'coord': {'lon': 34.25, 'lat': -8.1167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 65.23, 'feels_like': 68.14, 'temp_min': 65.23, 'temp_max': 65.23, 'pressure': 1013, 'humidity': 90, 'sea_level': 1013, 'grnd_level': 890}, 'visibility': 10000, 'wind': {'speed': 2.15, 'deg': 303}, 'clouds': {'all': 99}, 'dt': 1610745180, 'sys': {'country': 'TZ', 'sunrise': 1610768187, 'sunset': 1610813318}, 'timezone': 10800, 'id': 160141, 'name': 'Dunda', 'cod': 200}
# Processing Record 12 of Set 1 | praia da vitoria
# {'coord': {'lon': -27.0667, 'lat': 38.7333}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 60.46, 'feels_like': 54.05, 'temp_min': 60.01, 'temp_max': 60.8, 'pressure': 1022, 'humidity': 94}, 'visibility': 9000, 'wind': {'speed': 16.37, 'deg': 219}, 'rain': {'1h': 0.18}, 'clouds': {'all': 40}, 'dt': 1610745180, 'sys': {'type': 1, 'id': 6895, 'country': 'PT', 'sunrise': 1610701485, 'sunset': 1610736618}, 'timezone': -3600, 'id': 3372760, 'name': 'Praia da Vitória', 'cod': 200}
# Processing Record 13 of Set 1 | pella
# {'coord': {'lon': 30.8181, 'lat': 59.7775}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 5.16, 'feels_like': -3.59, 'temp_min': 0, 'temp_max': 8.6, 'pressure': 1015, 'humidity': 85}, 'visibility': 3100, 'wind': {'speed': 4.47, 'deg': 30}, 'snow': {'1h': 1}, 'clouds': {'all': 75}, 'dt': 1610745180, 'sys': {'type': 1, 'id': 8926, 'country': 'RU', 'sunrise': 1610779262, 'sunset': 1610803891}, 'timezone': 10800, 'id': 513898, 'name': 'Otradnoye', 'cod': 200}
# Processing Record 14 of Set 1 | tuktoyaktuk
# {'coord': {'lon': -133.0374, 'lat': 69.4541}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': -16.6, 'feels_like': -30.62, 'temp_min': -16.6, 'temp_max': -16.6, 'pressure': 1016, 'humidity': 76}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 100, 'gust': 18.41}, 'clouds': {'all': 75}, 'dt': 1610745180, 'sys': {'type': 1, 'id': 942, 'country': 'CA', 'sunrise': 1610741789, 'sunset': 1610747192}, 'timezone': -25200, 'id': 6170031, 'name': 'Tuktoyaktuk', 'cod': 200}
# Processing Record 15 of Set 1 | vaini
# {'coord': {'lon': -175.2, 'lat': -21.2}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 84.2, 'feels_like': 90.54, 'temp_min': 84.2, 'temp_max': 84.2, 'pressure': 1013, 'humidity': 79}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 10}, 'clouds': {'all': 40}, 'dt': 1610745181, 'sys': {'type': 1, 'id': 7285, 'country': 'TO', 'sunrise': 1610817168, 'sunset': 1610864898}, 'timezone': 46800, 'id': 4032243, 'name': 'Vaini', 'cod': 200}
# Processing Record 16 of Set 1 | ushuaia
# {'coord': {'lon': -68.3, 'lat': -54.8}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 62.6, 'feels_like': 57.36, 'temp_min': 62.6, 'temp_max': 62.6, 'pressure': 1011, 'humidity': 51}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 70}, 'clouds': {'all': 20}, 'dt': 1610745167, 'sys': {'type': 1, 'id': 8303, 'country': 'AR', 'sunrise': 1610698968, 'sunset': 1610758931}, 'timezone': -10800, 'id': 3833367, 'name': 'Ushuaia', 'cod': 200}
# Processing Record 17 of Set 1 | cape town
# {'coord': {'lon': 18.4232, 'lat': -33.9258}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 65.73, 'feels_like': 62.67, 'temp_min': 64, 'temp_max': 66.99, 'pressure': 1010, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 320}, 'clouds': {'all': 75}, 'dt': 1610744894, 'sys': {'type': 1, 'id': 1899, 'country': 'ZA', 'sunrise': 1610682655, 'sunset': 1610733608}, 'timezone': 7200, 'id': 3369157, 'name': 'Cape Town', 'cod': 200}
# Processing Record 18 of Set 1 | kaitangata
# {'coord': {'lon': 169.8464, 'lat': -46.2817}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 64.99, 'feels_like': 66.16, 'temp_min': 64.99, 'temp_max': 64.99, 'pressure': 1006, 'humidity': 76}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 293, 'gust': 5.01}, 'clouds': {'all': 44}, 'dt': 1610745181, 'sys': {'type': 3, 'id': 2000217, 'country': 'NZ', 'sunrise': 1610730587, 'sunset': 1610785816}, 'timezone': 46800, 'id': 2208248, 'name': 'Kaitangata', 'cod': 200}
# Processing Record 19 of Set 1 | cidreira
# {'coord': {'lon': -50.2056, 'lat': -30.1811}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 77.13, 'feels_like': 74.03, 'temp_min': 77.13, 'temp_max': 77.13, 'pressure': 1011, 'humidity': 82, 'sea_level': 1011, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 20.15, 'deg': 60}, 'clouds': {'all': 14}, 'dt': 1610745181, 'sys': {'country': 'BR', 'sunrise': 1610699647, 'sunset': 1610749566}, 'timezone': -10800, 'id': 3466165, 'name': 'Cidreira', 'cod': 200}
# Processing Record 20 of Set 1 | boa vista
# {'coord': {'lon': -60.6733, 'lat': 2.8197}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 86, 'feels_like': 85.89, 'temp_min': 86, 'temp_max': 86, 'pressure': 1007, 'humidity': 54}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 80}, 'clouds': {'all': 75}, 'dt': 1610745181, 'sys': {'type': 1, 'id': 8340, 'country': 'BR', 'sunrise': 1610705566, 'sunset': 1610748672}, 'timezone': -14400, 'id': 3664980, 'name': 'Boa Vista', 'cod': 200}
# Processing Record 21 of Set 1 | portland
# {'coord': {'lon': -122.6762, 'lat': 45.5234}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 48.2, 'feels_like': 46.8, 'temp_min': 46.99, 'temp_max': 50, 'pressure': 1030, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 0.22, 'deg': 14}, 'clouds': {'all': 90}, 'dt': 1610745065, 'sys': {'type': 1, 'id': 5321, 'country': 'US', 'sunrise': 1610725603, 'sunset': 1610758403}, 'timezone': -28800, 'id': 5746545, 'name': 'Portland', 'cod': 200}
# Processing Record 22 of Set 1 | barrow
# {'coord': {'lon': -156.7887, 'lat': 71.2906}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': -9.4, 'feels_like': -26.54, 'temp_min': -9.4, 'temp_max': -9.4, 'pressure': 1020, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 18.41, 'deg': 50}, 'clouds': {'all': 1}, 'dt': 1610745181, 'sys': {'type': 1, 'id': 7649, 'country': 'US', 'sunrise': 0, 'sunset': 0}, 'timezone': -32400, 'id': 5880054, 'name': 'Barrow', 'cod': 200}
# Processing Record 23 of Set 1 | nyurba
# {'coord': {'lon': 118.3319, 'lat': 63.2842}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -31.2, 'feels_like': -41.94, 'temp_min': -31.2, 'temp_max': -31.2, 'pressure': 1027, 'humidity': 83, 'sea_level': 1027, 'grnd_level': 1011}, 'visibility': 943, 'wind': {'speed': 6.55, 'deg': 29}, 'clouds': {'all': 100}, 'dt': 1610745181, 'sys': {'country': 'RU', 'sunrise': 1610760151, 'sunset': 1610780985}, 'timezone': 32400, 'id': 2018735, 'name': 'Nyurba', 'cod': 200}
# Processing Record 24 of Set 1 | busselton
# {'coord': {'lon': 115.3333, 'lat': -33.65}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 58.26, 'feels_like': 56.59, 'temp_min': 57, 'temp_max': 59, 'pressure': 1020, 'humidity': 79}, 'visibility': 10000, 'wind': {'speed': 4, 'deg': 111, 'gust': 10}, 'clouds': {'all': 0}, 'dt': 1610745181, 'sys': {'type': 3, 'id': 2020551, 'country': 'AU', 'sunrise': 1610745878, 'sunset': 1610796699}, 'timezone': 28800, 'id': 2075265, 'name': 'Busselton', 'cod': 200}
# Processing Record 25 of Set 1 | norrtalje
# {'coord': {'lon': 18.705, 'lat': 59.758}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 23.38, 'feels_like': 13.93, 'temp_min': 18, 'temp_max': 28.99, 'pressure': 1022, 'humidity': 89}, 'visibility': 10000, 'wind': {'speed': 8.01, 'deg': 242, 'gust': 14}, 'clouds': {'all': 86}, 'dt': 1610745182, 'sys': {'type': 3, 'id': 2017251, 'country': 'SE', 'sunrise': 1610695850, 'sunset': 1610720277}, 'timezone': 3600, 'id': 2688250, 'name': 'Norrtälje', 'cod': 200}
# Processing Record 26 of Set 1 | burnie
# {'coord': {'lon': 145.9167, 'lat': -41.0667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 53.01, 'feels_like': 44.19, 'temp_min': 53.01, 'temp_max': 53.01, 'pressure': 1016, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 14, 'deg': 192, 'gust': 18.01}, 'clouds': {'all': 91}, 'dt': 1610745182, 'sys': {'type': 3, 'id': 2018289, 'country': 'AU', 'sunrise': 1610737362, 'sunset': 1610790531}, 'timezone': 39600, 'id': 2173125, 'name': 'Burnie', 'cod': 200}
# Processing Record 27 of Set 1 | guerrero negro
# {'coord': {'lon': -114.0611, 'lat': 27.9769}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.53, 'feels_like': 73.2, 'temp_min': 80.53, 'temp_max': 80.53, 'pressure': 1015, 'humidity': 16, 'sea_level': 1015, 'grnd_level': 1015}, 'visibility': 10000, 'wind': {'speed': 6.2, 'deg': 280}, 'clouds': {'all': 0}, 'dt': 1610745087, 'sys': {'country': 'MX', 'sunrise': 1610720916, 'sunset': 1610758954}, 'timezone': -25200, 'id': 4021858, 'name': 'Guerrero Negro', 'cod': 200}
# Processing Record 28 of Set 1 | khandyga
# {'coord': {'lon': 135.6, 'lat': 62.6667}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -48.24, 'feels_like': -55.95, 'temp_min': -48.24, 'temp_max': -48.24, 'pressure': 1026, 'humidity': 76, 'sea_level': 1026, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 0.98, 'deg': 108}, 'clouds': {'all': 58}, 'dt': 1610745182, 'sys': {'country': 'RU', 'sunrise': 1610755632, 'sunset': 1610777213}, 'timezone': 32400, 'id': 2022773, 'name': 'Khandyga', 'cod': 200}
# Processing Record 29 of Set 1 | bethel
# {'coord': {'lon': -73.414, 'lat': 41.3712}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 38.8, 'feels_like': 30.92, 'temp_min': 37.99, 'temp_max': 39.99, 'pressure': 1014, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 100}, 'clouds': {'all': 90}, 'dt': 1610745182, 'sys': {'type': 1, 'id': 3888, 'country': 'US', 'sunrise': 1610713031, 'sunset': 1610747325}, 'timezone': -18000, 'id': 5282297, 'name': 'Bethel', 'cod': 200}
# Processing Record 30 of Set 1 | mount isa
# {'coord': {'lon': 139.5, 'lat': -20.7333}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 84.2, 'feels_like': 74.68, 'temp_min': 84.2, 'temp_max': 84.2, 'pressure': 1008, 'humidity': 23}, 'visibility': 10000, 'wind': {'speed': 13.8, 'deg': 170}, 'clouds': {'all': 17}, 'dt': 1610745182, 'sys': {'type': 1, 'id': 9495, 'country': 'AU', 'sunrise': 1610741654, 'sunset': 1610789320}, 'timezone': 36000, 'id': 2065594, 'name': 'Mount Isa', 'cod': 200}
# Processing Record 31 of Set 1 | port alfred
# {'coord': {'lon': 26.891, 'lat': -33.5906}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 69.01, 'feels_like': 74.01, 'temp_min': 69.01, 'temp_max': 69.01, 'pressure': 1005, 'humidity': 89}, 'visibility': 10000, 'wind': {'speed': 1.01, 'deg': 304, 'gust': 7}, 'clouds': {'all': 48}, 'dt': 1610744956, 'sys': {'type': 3, 'id': 2011314, 'country': 'ZA', 'sunrise': 1610680669, 'sunset': 1610731528}, 'timezone': 7200, 'id': 964432, 'name': 'Port Alfred', 'cod': 200}
# Processing Record 32 of Set 1 | taolanaro
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 33 of Set 1 | iqaluit
# {'coord': {'lon': -68.5145, 'lat': 63.7506}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 12.2, 'feels_like': -4.13, 'temp_min': 12.2, 'temp_max': 12.2, 'pressure': 1005, 'humidity': 79}, 'visibility': 10000, 'wind': {'speed': 18.41, 'deg': 140}, 'clouds': {'all': 90}, 'dt': 1610745182, 'sys': {'type': 1, 'id': 797, 'country': 'CA', 'sunrise': 1610718966, 'sunset': 1610739037}, 'timezone': -18000, 'id': 5983720, 'name': 'Iqaluit', 'cod': 200}
# Processing Record 34 of Set 1 | biel
# {'coord': {'lon': 7.2441, 'lat': 47.1324}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 24.21, 'feels_like': 16.39, 'temp_min': 21.99, 'temp_max': 27, 'pressure': 1026, 'humidity': 100}, 'visibility': 6000, 'wind': {'speed': 5.75, 'deg': 60}, 'clouds': {'all': 20}, 'dt': 1610745182, 'sys': {'type': 1, 'id': 6940, 'country': 'CH', 'sunrise': 1610694763, 'sunset': 1610726867}, 'timezone': 3600, 'id': 2661513, 'name': 'Biel/Bienne', 'cod': 200}
# Processing Record 35 of Set 1 | airai
# {'coord': {'lon': 125.4092, 'lat': -8.9266}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 62.46, 'feels_like': 66.16, 'temp_min': 62.46, 'temp_max': 62.46, 'pressure': 1005, 'humidity': 100, 'sea_level': 1005, 'grnd_level': 852}, 'visibility': 10000, 'wind': {'speed': 0.92, 'deg': 120}, 'clouds': {'all': 100}, 'dt': 1610745182, 'sys': {'country': 'TL', 'sunrise': 1610746225, 'sunset': 1610791514}, 'timezone': 32400, 'id': 1651810, 'name': 'Airai', 'cod': 200}
# Processing Record 36 of Set 1 | burica
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 37 of Set 1 | longyearbyen
# {'coord': {'lon': 15.6401, 'lat': 78.2186}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 21.2, 'feels_like': 12.76, 'temp_min': 21.2, 'temp_max': 21.2, 'pressure': 1010, 'humidity': 86}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 120}, 'clouds': {'all': 75}, 'dt': 1610745055, 'sys': {'type': 1, 'id': 1663, 'country': 'SJ', 'sunrise': 0, 'sunset': 0}, 'timezone': 3600, 'id': 2729907, 'name': 'Longyearbyen', 'cod': 200}
# Processing Record 38 of Set 1 | samusu
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 39 of Set 1 | north bend
# {'coord': {'lon': -124.2243, 'lat': 43.4065}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 56.91, 'feels_like': 57.36, 'temp_min': 53.01, 'temp_max': 60.01, 'pressure': 1030, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 1.07, 'deg': 225}, 'clouds': {'all': 40}, 'dt': 1610745169, 'sys': {'type': 1, 'id': 5239, 'country': 'US', 'sunrise': 1610725576, 'sunset': 1610759174}, 'timezone': -28800, 'id': 5742974, 'name': 'North Bend', 'cod': 200}
# Processing Record 40 of Set 1 | sao felix do xingu
# {'coord': {'lon': -51.995, 'lat': -6.6447}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 78.31, 'feels_like': 89.01, 'temp_min': 78.31, 'temp_max': 78.31, 'pressure': 1007, 'humidity': 94, 'sea_level': 1007, 'grnd_level': 984}, 'visibility': 10000, 'wind': {'speed': 0.94, 'deg': 59}, 'rain': {'1h': 0.1}, 'clouds': {'all': 100}, 'dt': 1610745183, 'sys': {'country': 'BR', 'sunrise': 1610702604, 'sunset': 1610747468}, 'timezone': -10800, 'id': 3388847, 'name': 'São Félix do Xingu', 'cod': 200}
# Processing Record 41 of Set 1 | kavieng
# {'coord': {'lon': 150.7967, 'lat': -2.5744}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 77.4, 'feels_like': 75.42, 'temp_min': 77.4, 'temp_max': 77.4, 'pressure': 1007, 'humidity': 90, 'sea_level': 1007, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 21.12, 'deg': 15}, 'rain': {'1h': 3.44}, 'clouds': {'all': 100}, 'dt': 1610745183, 'sys': {'country': 'PG', 'sunrise': 1610740724, 'sunset': 1610784826}, 'timezone': 36000, 'id': 2094342, 'name': 'Kavieng', 'cod': 200}
# Processing Record 42 of Set 1 | vila velha
# {'coord': {'lon': -40.2925, 'lat': -20.3297}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.29, 'feels_like': 82.09, 'temp_min': 80.01, 'temp_max': 80.6, 'pressure': 1013, 'humidity': 74}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 50}, 'clouds': {'all': 40}, 'dt': 1610745183, 'sys': {'type': 1, 'id': 8474, 'country': 'BR', 'sunrise': 1610698427, 'sunset': 1610746026}, 'timezone': -10800, 'id': 3445026, 'name': 'Vila Velha', 'cod': 200}
# Processing Record 43 of Set 1 | sao joao da barra
# {'coord': {'lon': -41.0511, 'lat': -21.6403}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.6, 'feels_like': 77.59, 'temp_min': 80.6, 'temp_max': 80.6, 'pressure': 1012, 'humidity': 69}, 'visibility': 10000, 'wind': {'speed': 18.41, 'deg': 60}, 'clouds': {'all': 0}, 'dt': 1610745183, 'sys': {'type': 1, 'id': 8337, 'country': 'BR', 'sunrise': 1610698466, 'sunset': 1610746351}, 'timezone': -10800, 'id': 3448903, 'name': 'São João da Barra', 'cod': 200}
# Processing Record 44 of Set 1 | jamestown
# {'coord': {'lon': -79.2353, 'lat': 42.097}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 40.75, 'feels_like': 27.16, 'temp_min': 39.2, 'temp_max': 42.01, 'pressure': 1002, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 17.27, 'deg': 140, 'gust': 26.46}, 'rain': {'1h': 0.21}, 'clouds': {'all': 90}, 'dt': 1610745183, 'sys': {'type': 1, 'id': 4588, 'country': 'US', 'sunrise': 1610714551, 'sunset': 1610748599}, 'timezone': -18000, 'id': 5122534, 'name': 'Jamestown', 'cod': 200}
# Processing Record 45 of Set 1 | ilulissat
# {'coord': {'lon': -51.1, 'lat': 69.2167}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 12.2, 'feels_like': -1.08, 'temp_min': 12.2, 'temp_max': 12.2, 'pressure': 1009, 'humidity': 67}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 110}, 'clouds': {'all': 20}, 'dt': 1610745183, 'sys': {'type': 1, 'id': 165, 'country': 'GL', 'sunrise': 1610721484, 'sunset': 1610728158}, 'timezone': -10800, 'id': 3423146, 'name': 'Ilulissat', 'cod': 200}
# Processing Record 46 of Set 1 | hilo
# {'coord': {'lon': -155.09, 'lat': 19.7297}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 77.72, 'feels_like': 77.7, 'temp_min': 73.99, 'temp_max': 82.4, 'pressure': 1019, 'humidity': 57}, 'visibility': 10000, 'wind': {'speed': 6.69, 'deg': 121}, 'clouds': {'all': 20}, 'dt': 1610745183, 'sys': {'type': 1, 'id': 7881, 'country': 'US', 'sunrise': 1610729855, 'sunset': 1610769714}, 'timezone': -36000, 'id': 5855927, 'name': 'Hilo', 'cod': 200}
# Processing Record 47 of Set 1 | ponta do sol
# {'coord': {'lon': -17.1, 'lat': 32.6667}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 50.13, 'feels_like': 45.14, 'temp_min': 48, 'temp_max': 53.01, 'pressure': 1029, 'humidity': 61}, 'visibility': 10000, 'wind': {'speed': 4, 'deg': 32, 'gust': 5.01}, 'clouds': {'all': 3}, 'dt': 1610745183, 'sys': {'type': 3, 'id': 2008291, 'country': 'PT', 'sunrise': 1610698231, 'sunset': 1610735087}, 'timezone': 0, 'id': 2264557, 'name': 'Ponta do Sol', 'cod': 200}
# Processing Record 48 of Set 1 | torbay
# {'coord': {'lon': -52.7314, 'lat': 47.6666}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}, {'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 30.47, 'feels_like': 14.13, 'temp_min': 28.99, 'temp_max': 32, 'pressure': 1010, 'humidity': 93}, 'visibility': 1609, 'wind': {'speed': 21.85, 'deg': 60, 'gust': 33.38}, 'rain': {'1h': 1.06}, 'clouds': {'all': 90}, 'dt': 1610745183, 'sys': {'type': 1, 'id': 998, 'country': 'CA', 'sunrise': 1610709265, 'sunset': 1610741160}, 'timezone': -12600, 'id': 6167817, 'name': 'Torbay', 'cod': 200}
# Processing Record 49 of Set 1 | kapaa
# {'coord': {'lon': -159.319, 'lat': 22.0752}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 78.91, 'feels_like': 83.39, 'temp_min': 78.8, 'temp_max': 79, 'pressure': 1019, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 170}, 'clouds': {'all': 1}, 'dt': 1610744688, 'sys': {'type': 1, 'id': 7873, 'country': 'US', 'sunrise': 1610731117, 'sunset': 1610770483}, 'timezone': -36000, 'id': 5848280, 'name': 'Kapaa', 'cod': 200}
# Processing Record 50 of Set 1 | hoi an
# {'coord': {'lon': 108.335, 'lat': 15.8794}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 60.8, 'feels_like': 63.73, 'temp_min': 60.8, 'temp_max': 60.8, 'pressure': 1013, 'humidity': 100}, 'visibility': 6000, 'wind': {'speed': 1.14, 'deg': 210}, 'clouds': {'all': 75}, 'dt': 1610745183, 'sys': {'type': 1, 'id': 9306, 'country': 'VN', 'sunrise': 1610752646, 'sunset': 1610793290}, 'timezone': 25200, 'id': 1580541, 'name': 'Hoi An', 'cod': 200}
# Processing Record 1 of Set 2 | bluff
# {'coord': {'lon': 168.3333, 'lat': -46.6}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 58.21, 'feels_like': 58.57, 'temp_min': 58.21, 'temp_max': 58.21, 'pressure': 1008, 'humidity': 87, 'sea_level': 1008, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 1.77, 'deg': 295}, 'clouds': {'all': 98}, 'dt': 1610745184, 'sys': {'country': 'NZ', 'sunrise': 1610730881, 'sunset': 1610786250}, 'timezone': 46800, 'id': 2206939, 'name': 'Bluff', 'cod': 200}
# Processing Record 2 of Set 2 | chuy
# {'coord': {'lon': -53.4616, 'lat': -33.6971}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 78.1, 'feels_like': 76.59, 'temp_min': 78.1, 'temp_max': 78.1, 'pressure': 1009, 'humidity': 72, 'sea_level': 1009, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 14.76, 'deg': 54}, 'clouds': {'all': 80}, 'dt': 1610745184, 'sys': {'country': 'UY', 'sunrise': 1610699951, 'sunset': 1610750824}, 'timezone': -10800, 'id': 3443061, 'name': 'Chui', 'cod': 200}
# Processing Record 3 of Set 2 | upernavik
# {'coord': {'lon': -56.1549, 'lat': 72.7868}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 14.99, 'feels_like': 7.21, 'temp_min': 14.99, 'temp_max': 14.99, 'pressure': 1009, 'humidity': 95, 'sea_level': 1009, 'grnd_level': 1009}, 'visibility': 468, 'wind': {'speed': 4, 'deg': 86}, 'clouds': {'all': 100}, 'dt': 1610745184, 'sys': {'country': 'GL', 'sunrise': 0, 'sunset': 0}, 'timezone': -10800, 'id': 3418910, 'name': 'Upernavik', 'cod': 200}
# Processing Record 4 of Set 2 | nabire
# {'coord': {'lon': 135.4833, 'lat': -3.3667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 76.19, 'feels_like': 82.53, 'temp_min': 76.19, 'temp_max': 76.19, 'pressure': 1007, 'humidity': 86, 'sea_level': 1007, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 3.85, 'deg': 181}, 'clouds': {'all': 100}, 'dt': 1610745184, 'sys': {'country': 'ID', 'sunrise': 1610744327, 'sunset': 1610788575}, 'timezone': 32400, 'id': 1634614, 'name': 'Nabire', 'cod': 200}
# Processing Record 5 of Set 2 | bredasdorp
# {'coord': {'lon': 20.0403, 'lat': -34.5322}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 68, 'feels_like': 61.99, 'temp_min': 68, 'temp_max': 68, 'pressure': 1008, 'humidity': 60}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 330}, 'clouds': {'all': 0}, 'dt': 1610745184, 'sys': {'type': 1, 'id': 1966, 'country': 'ZA', 'sunrise': 1610682179, 'sunset': 1610733307}, 'timezone': 7200, 'id': 1015776, 'name': 'Bredasdorp', 'cod': 200}
# Processing Record 6 of Set 2 | svebolle
# {'coord': {'lon': 11.2866, 'lat': 55.6518}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 29.01, 'feels_like': 19.94, 'temp_min': 28, 'temp_max': 30, 'pressure': 1024, 'humidity': 82}, 'visibility': 10000, 'wind': {'speed': 8.01, 'deg': 320, 'gust': 15.01}, 'clouds': {'all': 82}, 'dt': 1610745184, 'sys': {'type': 3, 'id': 2009792, 'country': 'DK', 'sunrise': 1610696037, 'sunset': 1610723652}, 'timezone': 3600, 'id': 2612057, 'name': 'Svebølle', 'cod': 200}
# Processing Record 7 of Set 2 | mataura
# {'coord': {'lon': 168.8643, 'lat': -46.1927}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 65.3, 'feels_like': 64.89, 'temp_min': 65.3, 'temp_max': 65.3, 'pressure': 1008, 'humidity': 64, 'sea_level': 1008, 'grnd_level': 1002}, 'visibility': 10000, 'wind': {'speed': 2.3, 'deg': 296}, 'clouds': {'all': 22}, 'dt': 1610745184, 'sys': {'country': 'NZ', 'sunrise': 1610730843, 'sunset': 1610786033}, 'timezone': 46800, 'id': 6201424, 'name': 'Mataura', 'cod': 200}
# Processing Record 8 of Set 2 | sitka
# {'coord': {'lon': -135.33, 'lat': 57.0531}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 44.6, 'feels_like': 35.74, 'temp_min': 44.6, 'temp_max': 44.6, 'pressure': 1008, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 200}, 'rain': {'1h': 0.51, '3h': 0.51}, 'clouds': {'all': 75}, 'dt': 1610745184, 'sys': {'type': 1, 'id': 7795, 'country': 'US', 'sunrise': 1610731684, 'sunset': 1610758398}, 'timezone': -32400, 'id': 5557293, 'name': 'Sitka', 'cod': 200}
# Processing Record 9 of Set 2 | nizhneyansk
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 10 of Set 2 | mar del plata
# {'coord': {'lon': -57.5575, 'lat': -38.0023}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 74.41, 'feels_like': 70.63, 'temp_min': 72, 'temp_max': 77, 'pressure': 1006, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 13.8, 'deg': 360}, 'clouds': {'all': 75}, 'dt': 1610745010, 'sys': {'type': 1, 'id': 8305, 'country': 'AR', 'sunrise': 1610700285, 'sunset': 1610752457}, 'timezone': -10800, 'id': 3430863, 'name': 'Mar del Plata', 'cod': 200}
# Processing Record 11 of Set 2 | mana
# {'coord': {'lon': -53.7767, 'lat': 5.6592}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 78.08, 'feels_like': 80.98, 'temp_min': 78.08, 'temp_max': 78.08, 'pressure': 1009, 'humidity': 86, 'sea_level': 1009, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 11.74, 'deg': 64}, 'clouds': {'all': 72}, 'dt': 1610745184, 'sys': {'country': 'GF', 'sunrise': 1610704174, 'sunset': 1610746753}, 'timezone': -10800, 'id': 3381041, 'name': 'Mana', 'cod': 200}
# Processing Record 12 of Set 2 | hermanus
# {'coord': {'lon': 19.2345, 'lat': -34.4187}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 63, 'feels_like': 58.39, 'temp_min': 63, 'temp_max': 63, 'pressure': 1009, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 12.55, 'deg': 298}, 'clouds': {'all': 0}, 'dt': 1610745184, 'sys': {'type': 3, 'id': 2006131, 'country': 'ZA', 'sunrise': 1610682389, 'sunset': 1610733484}, 'timezone': 7200, 'id': 3366880, 'name': 'Hermanus', 'cod': 200}
# Processing Record 13 of Set 2 | geraldton
# {'coord': {'lon': 114.6, 'lat': -28.7667}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 82.4, 'feels_like': 71.62, 'temp_min': 82.4, 'temp_max': 82.4, 'pressure': 1008, 'humidity': 39}, 'visibility': 10000, 'wind': {'speed': 21.85, 'deg': 70, 'gust': 34.52}, 'clouds': {'all': 0}, 'dt': 1610745184, 'sys': {'type': 1, 'id': 9522, 'country': 'AU', 'sunrise': 1610746702, 'sunset': 1610796227}, 'timezone': 28800, 'id': 2070998, 'name': 'Geraldton', 'cod': 200}
# Processing Record 14 of Set 2 | altay
# {'coord': {'lon': 88.1167, 'lat': 47.8667}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': -3.1, 'feels_like': -11.49, 'temp_min': -3.1, 'temp_max': -3.1, 'pressure': 1050, 'humidity': 55, 'sea_level': 1050, 'grnd_level': 932}, 'visibility': 10000, 'wind': {'speed': 2.86, 'deg': 61}, 'clouds': {'all': 0}, 'dt': 1610745184, 'sys': {'country': 'CN', 'sunrise': 1610761879, 'sunset': 1610793764}, 'timezone': 28800, 'id': 1529651, 'name': 'Altay', 'cod': 200}
# Processing Record 15 of Set 2 | grajau
# {'coord': {'lon': -46.1386, 'lat': -5.8194}, 'weather': [{'id': 502, 'main': 'Rain', 'description': 'heavy intensity rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 77.32, 'feels_like': 85.89, 'temp_min': 77.32, 'temp_max': 77.32, 'pressure': 1008, 'humidity': 90, 'sea_level': 1008, 'grnd_level': 991}, 'visibility': 10000, 'wind': {'speed': 2.3, 'deg': 76}, 'rain': {'1h': 4.211}, 'clouds': {'all': 98}, 'dt': 1610745184, 'sys': {'country': 'BR', 'sunrise': 1610701275, 'sunset': 1610745985}, 'timezone': -10800, 'id': 3398856, 'name': 'Grajaú', 'cod': 200}
# Processing Record 16 of Set 2 | paamiut
# {'coord': {'lon': -49.6678, 'lat': 61.994}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 28.08, 'feels_like': 14.14, 'temp_min': 28.08, 'temp_max': 28.08, 'pressure': 1007, 'humidity': 95, 'sea_level': 1007, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 17.16, 'deg': 179}, 'snow': {'1h': 0.16}, 'clouds': {'all': 100}, 'dt': 1610745185, 'sys': {'country': 'GL', 'sunrise': 1610713365, 'sunset': 1610735589}, 'timezone': -10800, 'id': 3421193, 'name': 'Paamiut', 'cod': 200}
# Processing Record 17 of Set 2 | hobart
# {'coord': {'lon': 147.3294, 'lat': -42.8794}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 56.21, 'feels_like': 47.17, 'temp_min': 55, 'temp_max': 57.2, 'pressure': 1003, 'humidity': 58}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 250}, 'rain': {'1h': 0.87}, 'clouds': {'all': 75}, 'dt': 1610745000, 'sys': {'type': 1, 'id': 9545, 'country': 'AU', 'sunrise': 1610736690, 'sunset': 1610790525}, 'timezone': 39600, 'id': 2163355, 'name': 'Hobart', 'cod': 200}
# Processing Record 18 of Set 2 | atuona
# {'coord': {'lon': -139.0333, 'lat': -9.8}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 77.23, 'feels_like': 77.5, 'temp_min': 77.23, 'temp_max': 77.23, 'pressure': 1013, 'humidity': 78, 'sea_level': 1013, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 12.93, 'deg': 68}, 'clouds': {'all': 1}, 'dt': 1610745185, 'sys': {'country': 'PF', 'sunrise': 1610723200, 'sunset': 1610768660}, 'timezone': -34200, 'id': 4020109, 'name': 'Atuona', 'cod': 200}
# Processing Record 19 of Set 2 | dikson
# {'coord': {'lon': 80.5464, 'lat': 73.5069}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -31.97, 'feels_like': -41.58, 'temp_min': -31.97, 'temp_max': -31.97, 'pressure': 1033, 'humidity': 80, 'sea_level': 1033, 'grnd_level': 1027}, 'visibility': 10000, 'wind': {'speed': 4.52, 'deg': 125}, 'clouds': {'all': 67}, 'dt': 1610745185, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 25200, 'id': 1507390, 'name': 'Dikson', 'cod': 200}
# Processing Record 20 of Set 2 | puerto ayora
# {'coord': {'lon': -90.3518, 'lat': -0.7393}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 79.72, 'feels_like': 83.91, 'temp_min': 78.01, 'temp_max': 82.4, 'pressure': 1010, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 260}, 'clouds': {'all': 40}, 'dt': 1610745185, 'sys': {'type': 1, 'id': 8521, 'country': 'EC', 'sunrise': 1610712362, 'sunset': 1610756125}, 'timezone': -21600, 'id': 3652764, 'name': 'Puerto Ayora', 'cod': 200}
# Processing Record 21 of Set 2 | los llanos de aridane
# {'coord': {'lon': -17.9182, 'lat': 28.6585}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 58.14, 'feels_like': 51.49, 'temp_min': 54, 'temp_max': 64.4, 'pressure': 1028, 'humidity': 52}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 30, 'gust': 19.57}, 'clouds': {'all': 75}, 'dt': 1610745185, 'sys': {'type': 1, 'id': 2377, 'country': 'ES', 'sunrise': 1610697925, 'sunset': 1610735786}, 'timezone': 0, 'id': 2514651, 'name': 'Los Llanos de Aridane', 'cod': 200}
# Processing Record 22 of Set 2 | khatanga
# {'coord': {'lon': 102.5, 'lat': 71.9667}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': -47.63, 'feels_like': -56.13, 'temp_min': -47.63, 'temp_max': -47.63, 'pressure': 1039, 'humidity': 76, 'sea_level': 1039, 'grnd_level': 1035}, 'visibility': 10000, 'wind': {'speed': 2.39, 'deg': 62}, 'clouds': {'all': 36}, 'dt': 1610745185, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 25200, 'id': 2022572, 'name': 'Khatanga', 'cod': 200}
# Processing Record 23 of Set 2 | ambovombe
# {'coord': {'lon': 46.0833, 'lat': -25.1667}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 76.06, 'feels_like': 82.58, 'temp_min': 76.06, 'temp_max': 76.06, 'pressure': 1009, 'humidity': 92, 'sea_level': 1009, 'grnd_level': 994}, 'visibility': 10000, 'wind': {'speed': 5.35, 'deg': 79}, 'clouds': {'all': 46}, 'dt': 1610745185, 'sys': {'country': 'MG', 'sunrise': 1610763589, 'sunset': 1610812235}, 'timezone': 10800, 'id': 1079048, 'name': 'Ambovombe', 'cod': 200}
# Processing Record 24 of Set 2 | griffith
# {'coord': {'lon': -87.4237, 'lat': 41.5284}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 33.28, 'feels_like': 28.42, 'temp_min': 32, 'temp_max': 34, 'pressure': 1000, 'humidity': 100}, 'visibility': 6437, 'wind': {'speed': 2.62, 'deg': 159}, 'clouds': {'all': 90}, 'dt': 1610744890, 'sys': {'type': 1, 'id': 4505, 'country': 'US', 'sunrise': 1610716418, 'sunset': 1610750663}, 'timezone': -21600, 'id': 4920986, 'name': 'Griffith', 'cod': 200}
# Processing Record 25 of Set 2 | bolshegrivskoye
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 26 of Set 2 | bambous virieux
# {'coord': {'lon': 57.7575, 'lat': -20.3428}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 79.81, 'feels_like': 87.4, 'temp_min': 78.8, 'temp_max': 81, 'pressure': 1011, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 80}, 'clouds': {'all': 75}, 'dt': 1610745185, 'sys': {'type': 1, 'id': 2061, 'country': 'MU', 'sunrise': 1610761323, 'sunset': 1610808896}, 'timezone': 14400, 'id': 1106677, 'name': 'Bambous Virieux', 'cod': 200}
# Processing Record 27 of Set 2 | naze
# {'coord': {'lon': 129.4833, 'lat': 28.3667}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 59.94, 'feels_like': 56.08, 'temp_min': 59.94, 'temp_max': 59.94, 'pressure': 1018, 'humidity': 72, 'sea_level': 1018, 'grnd_level': 990}, 'visibility': 10000, 'wind': {'speed': 7.43, 'deg': 335}, 'clouds': {'all': 1}, 'dt': 1610745186, 'sys': {'country': 'JP', 'sunrise': 1610748909, 'sunset': 1610786873}, 'timezone': 32400, 'id': 1855540, 'name': 'Naze', 'cod': 200}
# Processing Record 28 of Set 2 | new norfolk
# {'coord': {'lon': 147.0587, 'lat': -42.7826}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 53.82, 'feels_like': 50.88, 'temp_min': 48.99, 'temp_max': 57.99, 'pressure': 1004, 'humidity': 71}, 'visibility': 10000, 'wind': {'speed': 3, 'deg': 206, 'gust': 8.01}, 'clouds': {'all': 70}, 'dt': 1610745186, 'sys': {'type': 3, 'id': 2031307, 'country': 'AU', 'sunrise': 1610736773, 'sunset': 1610790571}, 'timezone': 39600, 'id': 2155415, 'name': 'New Norfolk', 'cod': 200}
# Processing Record 29 of Set 2 | belushya guba
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 30 of Set 2 | rikitea
# {'coord': {'lon': -134.9692, 'lat': -23.1203}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 78.66, 'feels_like': 80.78, 'temp_min': 78.66, 'temp_max': 78.66, 'pressure': 1016, 'humidity': 67, 'sea_level': 1016, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 7.02, 'deg': 38}, 'clouds': {'all': 29}, 'dt': 1610744688, 'sys': {'country': 'PF', 'sunrise': 1610720853, 'sunset': 1610769056}, 'timezone': -32400, 'id': 4030556, 'name': 'Rikitea', 'cod': 200}
# Processing Record 31 of Set 2 | hofn
# {'coord': {'lon': -15.2082, 'lat': 64.2539}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 38.64, 'feels_like': 24.42, 'temp_min': 38.64, 'temp_max': 38.64, 'pressure': 1004, 'humidity': 93, 'sea_level': 1004, 'grnd_level': 1003}, 'visibility': 521, 'wind': {'speed': 20.27, 'deg': 55}, 'rain': {'1h': 3.0076}, 'clouds': {'all': 100}, 'dt': 1610745186, 'sys': {'country': 'IS', 'sunrise': 1610706548, 'sunset': 1610725862}, 'timezone': 0, 'id': 2630299, 'name': 'Hofn', 'cod': 200}
# Processing Record 32 of Set 2 | albany
# {'coord': {'lon': -73.9662, 'lat': 42.6001}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 36.79, 'feels_like': 27.61, 'temp_min': 35.01, 'temp_max': 39, 'pressure': 1011, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 9.19, 'deg': 129}, 'clouds': {'all': 100}, 'dt': 1610745186, 'sys': {'type': 3, 'id': 19530, 'country': 'US', 'sunrise': 1610713374, 'sunset': 1610747246}, 'timezone': -18000, 'id': 5106841, 'name': 'Albany', 'cod': 200}
# Processing Record 33 of Set 2 | marcona
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 34 of Set 2 | norman wells
# {'coord': {'lon': -126.8329, 'lat': 65.282}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 5, 'feels_like': -3.17, 'temp_min': 5, 'temp_max': 5, 'pressure': 1007, 'humidity': 85}, 'visibility': 2414, 'wind': {'speed': 3.44, 'deg': 90}, 'clouds': {'all': 90}, 'dt': 1610745186, 'sys': {'type': 1, 'id': 951, 'country': 'CA', 'sunrise': 1610734097, 'sunset': 1610751906}, 'timezone': -25200, 'id': 6089245, 'name': 'Norman Wells', 'cod': 200}
# Processing Record 35 of Set 2 | junagarh
# {'coord': {'lon': 82.9333, 'lat': 19.8667}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 57.45, 'feels_like': 54.75, 'temp_min': 57.45, 'temp_max': 57.45, 'pressure': 1012, 'humidity': 51, 'sea_level': 1012, 'grnd_level': 986}, 'visibility': 10000, 'wind': {'speed': 0.67, 'deg': 206}, 'clouds': {'all': 0}, 'dt': 1610745186, 'sys': {'country': 'IN', 'sunrise': 1610759145, 'sunset': 1610798987}, 'timezone': 19800, 'id': 1268772, 'name': 'Jūnāgarh', 'cod': 200}
# Processing Record 36 of Set 2 | esperance
# {'coord': {'lon': 121.9, 'lat': -33.8667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 55.4, 'feels_like': 50.61, 'temp_min': 55.4, 'temp_max': 55.4, 'pressure': 1024, 'humidity': 71}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 90}, 'clouds': {'all': 90}, 'dt': 1610745186, 'sys': {'type': 1, 'id': 9525, 'country': 'AU', 'sunrise': 1610744270, 'sunset': 1610795154}, 'timezone': 28800, 'id': 2071860, 'name': 'Esperance', 'cod': 200}
# Processing Record 37 of Set 2 | yarmouth
# {'coord': {'lon': -70.2286, 'lat': 41.7057}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 41.68, 'feels_like': 34.21, 'temp_min': 39.99, 'temp_max': 43, 'pressure': 1017, 'humidity': 56}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 60}, 'clouds': {'all': 1}, 'dt': 1610745187, 'sys': {'type': 1, 'id': 4454, 'country': 'US', 'sunrise': 1610712323, 'sunset': 1610746503}, 'timezone': -18000, 'id': 4956335, 'name': 'Yarmouth', 'cod': 200}
# Processing Record 38 of Set 2 | eenhana
# {'coord': {'lon': 16.3333, 'lat': -17.4667}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 78.8, 'feels_like': 77.56, 'temp_min': 78.8, 'temp_max': 78.8, 'pressure': 1011, 'humidity': 36}, 'visibility': 10000, 'wind': {'speed': 2.15, 'deg': 265}, 'clouds': {'all': 5}, 'dt': 1610745187, 'sys': {'type': 1, 'id': 2267, 'country': 'NA', 'sunrise': 1610685134, 'sunset': 1610732132}, 'timezone': 7200, 'id': 3357804, 'name': 'Eenhana', 'cod': 200}
# Processing Record 39 of Set 2 | tiksi
# ...
# Processing Record 31 of Set 15 | kyra
# {'coord': {'lon': 111.9753, 'lat': 49.5776}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -4.61, 'feels_like': -16.96, 'temp_min': -4.61, 'temp_max': -4.61, 'pressure': 1033, 'humidity': 80, 'sea_level': 1033, 'grnd_level': 915}, 'visibility': 10000, 'wind': {'speed': 10.16, 'deg': 289}, 'clouds': {'all': 60}, 'dt': 1610745233, 'sys': {'country': 'RU', 'sunrise': 1610756541, 'sunset': 1610787648}, 'timezone': 32400, 'id': 2021041, 'name': 'Kyra', 'cod': 200}
# Processing Record 32 of Set 15 | walvis bay
# {'coord': {'lon': 14.5053, 'lat': -22.9575}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 70.38, 'feels_like': 70.9, 'temp_min': 69.8, 'temp_max': 71.01, 'pressure': 1014, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 250}, 'clouds': {'all': 42}, 'dt': 1610745234, 'sys': {'type': 1, 'id': 2288, 'country': 'NA', 'sunrise': 1610684980, 'sunset': 1610733164}, 'timezone': 7200, 'id': 3359638, 'name': 'Walvis Bay', 'cod': 200}
# Processing Record 33 of Set 15 | genhe
# {'coord': {'lon': 121.5167, 'lat': 50.7833}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -24.5, 'feels_like': -33.14, 'temp_min': -24.5, 'temp_max': -24.5, 'pressure': 1028, 'humidity': 84, 'sea_level': 1028, 'grnd_level': 931}, 'visibility': 2136, 'wind': {'speed': 2.95, 'deg': 223}, 'clouds': {'all': 92}, 'dt': 1610745234, 'sys': {'country': 'CN', 'sunrise': 1610754543, 'sunset': 1610785064}, 'timezone': 28800, 'id': 2037252, 'name': 'Genhe', 'cod': 200}
# Processing Record 34 of Set 15 | broome
# {'coord': {'lon': -75.833, 'lat': 42.2506}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 35.87, 'feels_like': 23.23, 'temp_min': 33.8, 'temp_max': 37, 'pressure': 1008, 'humidity': 86}, 'visibility': 10000, 'wind': {'speed': 16.11, 'deg': 150, 'gust': 31.07}, 'clouds': {'all': 90}, 'dt': 1610745234, 'sys': {'type': 1, 'id': 3429, 'country': 'US', 'sunrise': 1610713761, 'sunset': 1610747755}, 'timezone': -18000, 'id': 5110365, 'name': 'Broome', 'cod': 200}
# Processing Record 35 of Set 15 | gold coast
# {'coord': {'lon': 153.4333, 'lat': -28}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 76.46, 'feels_like': 78.73, 'temp_min': 75.2, 'temp_max': 78.01, 'pressure': 1006, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 330}, 'clouds': {'all': 46}, 'dt': 1610745139, 'sys': {'type': 1, 'id': 9486, 'country': 'AU', 'sunrise': 1610737472, 'sunset': 1610786812}, 'timezone': 36000, 'id': 2165087, 'name': 'Gold Coast', 'cod': 200}
# Processing Record 36 of Set 15 | verkhoyansk
# {'coord': {'lon': 133.385, 'lat': 67.5447}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -33.2, 'feels_like': -41.1, 'temp_min': -33.2, 'temp_max': -33.2, 'pressure': 1027, 'humidity': 81, 'sea_level': 1027, 'grnd_level': 1008}, 'visibility': 372, 'wind': {'speed': 1.48, 'deg': 120}, 'clouds': {'all': 100}, 'dt': 1610745234, 'sys': {'country': 'RU', 'sunrise': 1610760340, 'sunset': 1610773570}, 'timezone': 36000, 'id': 2013465, 'name': 'Verkhoyansk', 'cod': 200}
# Processing Record 37 of Set 15 | albury
# {'coord': {'lon': 146.9167, 'lat': -36.0833}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 53.4, 'feels_like': 46.24, 'temp_min': 53.01, 'temp_max': 54, 'pressure': 1013, 'humidity': 71}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 250}, 'clouds': {'all': 0}, 'dt': 1610745234, 'sys': {'type': 1, 'id': 9540, 'country': 'AU', 'sunrise': 1610737937, 'sunset': 1610789475}, 'timezone': 39600, 'id': 2178174, 'name': 'Albury', 'cod': 200}
# Processing Record 38 of Set 15 | yining
# {'coord': {'lon': 114.5636, 'lat': 29.0361}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 43.57, 'feels_like': 38.03, 'temp_min': 43.57, 'temp_max': 43.57, 'pressure': 1021, 'humidity': 72, 'sea_level': 1021, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 4.36, 'deg': 44}, 'clouds': {'all': 22}, 'dt': 1610745234, 'sys': {'country': 'CN', 'sunrise': 1610752570, 'sunset': 1610790376}, 'timezone': 28800, 'id': 1786538, 'name': 'Yining', 'cod': 200}
# Processing Record 39 of Set 15 | cacoal
# {'coord': {'lon': -61.4472, 'lat': -11.4386}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 78.35, 'feels_like': 86.38, 'temp_min': 78.35, 'temp_max': 78.35, 'pressure': 1006, 'humidity': 90, 'sea_level': 1006, 'grnd_level': 985}, 'visibility': 10000, 'wind': {'speed': 4.32, 'deg': 349}, 'rain': {'1h': 0.133}, 'clouds': {'all': 93}, 'dt': 1610745096, 'sys': {'country': 'BR', 'sunrise': 1610704414, 'sunset': 1610750195}, 'timezone': -14400, 'id': 3925212, 'name': 'Cacoal', 'cod': 200}
# Processing Record 40 of Set 15 | mogadishu
# {'coord': {'lon': 45.3438, 'lat': 2.0371}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 76.95, 'feels_like': 75.04, 'temp_min': 76.95, 'temp_max': 76.95, 'pressure': 1009, 'humidity': 84, 'sea_level': 1009, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 18.52, 'deg': 79}, 'clouds': {'all': 0}, 'dt': 1610745093, 'sys': {'country': 'SO', 'sunrise': 1610766463, 'sunset': 1610809716}, 'timezone': 10800, 'id': 53654, 'name': 'Mogadishu', 'cod': 200}
# Processing Record 41 of Set 15 | nigran
# {'coord': {'lon': -8.8066, 'lat': 42.1415}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 45.45, 'feels_like': 39.42, 'temp_min': 39.2, 'temp_max': 50, 'pressure': 1030, 'humidity': 93}, 'visibility': 9000, 'wind': {'speed': 8.05, 'deg': 200}, 'clouds': {'all': 4}, 'dt': 1610745158, 'sys': {'type': 1, 'id': 6440, 'country': 'ES', 'sunrise': 1610697661, 'sunset': 1610731675}, 'timezone': 3600, 'id': 3115463, 'name': 'Nigrán', 'cod': 200}
# Processing Record 42 of Set 15 | coria
# {'coord': {'lon': -6.5377, 'lat': 39.9879}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 35.35, 'feels_like': 29.75, 'temp_min': 35.35, 'temp_max': 35.35, 'pressure': 1030, 'humidity': 87, 'sea_level': 1030, 'grnd_level': 997}, 'visibility': 10000, 'wind': {'speed': 3.56, 'deg': 46}, 'clouds': {'all': 15}, 'dt': 1610745234, 'sys': {'country': 'ES', 'sunrise': 1610696757, 'sunset': 1610731490}, 'timezone': 3600, 'id': 2519234, 'name': 'Coria', 'cod': 200}
# Processing Record 43 of Set 15 | appingedam
# {'coord': {'lon': 6.8583, 'lat': 53.3217}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 34.18, 'feels_like': 29.93, 'temp_min': 33.01, 'temp_max': 35.01, 'pressure': 1029, 'humidity': 89}, 'visibility': 10000, 'wind': {'speed': 1.01, 'deg': 216, 'gust': 1.99}, 'clouds': {'all': 100}, 'dt': 1610745234, 'sys': {'type': 3, 'id': 2002264, 'country': 'NL', 'sunrise': 1610696377, 'sunset': 1610725438}, 'timezone': 3600, 'id': 2759687, 'name': 'Appingedam', 'cod': 200}
# Processing Record 44 of Set 15 | la seyne-sur-mer
# {'coord': {'lon': 5.8847, 'lat': 43.0982}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 42.49, 'feels_like': 36.27, 'temp_min': 39.99, 'temp_max': 44.01, 'pressure': 1015, 'humidity': 59}, 'visibility': 10000, 'wind': {'speed': 4, 'deg': 242, 'gust': 7}, 'clouds': {'all': 54}, 'dt': 1610745234, 'sys': {'type': 3, 'id': 2002422, 'country': 'FR', 'sunrise': 1610694305, 'sunset': 1610727977}, 'timezone': 3600, 'id': 3006414, 'name': 'La Seyne-sur-Mer', 'cod': 200}
# Processing Record 45 of Set 15 | tavai
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 46 of Set 15 | cheyur
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 47 of Set 15 | rayong
# {'coord': {'lon': 101.4333, 'lat': 12.8333}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 70, 'feels_like': 74.64, 'temp_min': 70, 'temp_max': 70, 'pressure': 1007, 'humidity': 91}, 'visibility': 10000, 'wind': {'speed': 2.93, 'deg': 158}, 'clouds': {'all': 0}, 'dt': 1610745234, 'sys': {'type': 3, 'id': 2001084, 'country': 'TH', 'sunrise': 1610754006, 'sunset': 1610795244}, 'timezone': 25200, 'id': 1607016, 'name': 'Rayong', 'cod': 200}
# Processing Record 48 of Set 15 | bababe
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 49 of Set 15 | hunza
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 50 of Set 15 | damietta
# {'coord': {'lon': 31.8133, 'lat': 31.4165}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 59, 'feels_like': 57.65, 'temp_min': 59, 'temp_max': 59, 'pressure': 1015, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 180}, 'clouds': {'all': 0}, 'dt': 1610745235, 'sys': {'type': 1, 'id': 2522, 'country': 'EG', 'sunrise': 1610686332, 'sunset': 1610723502}, 'timezone': 7200, 'id': 358048, 'name': 'Damietta', 'cod': 200}
# Processing Record 1 of Set 16 | porto novo
# {'coord': {'lon': 2.6036, 'lat': 6.4965}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 82.4, 'feels_like': 86.65, 'temp_min': 82.4, 'temp_max': 82.4, 'pressure': 1009, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 210}, 'clouds': {'all': 20}, 'dt': 1610745235, 'sys': {'type': 1, 'id': 1119, 'country': 'BJ', 'sunrise': 1610690718, 'sunset': 1610733140}, 'timezone': 3600, 'id': 2392087, 'name': 'Porto-Novo', 'cod': 200}
# Processing Record 2 of Set 16 | adrar
# {'coord': {'lon': -10.0711, 'lat': 20.5022}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 62.17, 'feels_like': 51.76, 'temp_min': 62.17, 'temp_max': 62.17, 'pressure': 1019, 'humidity': 26, 'sea_level': 1019, 'grnd_level': 974}, 'visibility': 10000, 'wind': {'speed': 10.92, 'deg': 60}, 'clouds': {'all': 100}, 'dt': 1610745235, 'sys': {'country': 'MR', 'sunrise': 1610695130, 'sunset': 1610734813}, 'timezone': 0, 'id': 2381972, 'name': 'Adrar', 'cod': 200}
# Processing Record 3 of Set 16 | gualaceo
# {'coord': {'lon': -78.7833, 'lat': -2.9}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 62.6, 'feels_like': 55.24, 'temp_min': 62.6, 'temp_max': 62.6, 'pressure': 1020, 'humidity': 72}, 'visibility': 10000, 'wind': {'speed': 14.97, 'deg': 240}, 'rain': {'1h': 0.57}, 'clouds': {'all': 75}, 'dt': 1610745235, 'sys': {'type': 1, 'id': 8519, 'country': 'EC', 'sunrise': 1610709385, 'sunset': 1610753548}, 'timezone': -18000, 'id': 3657670, 'name': 'Gualaceo', 'cod': 200}
# Processing Record 4 of Set 16 | salani
# {'coord': {'lon': 79.7127, 'lat': 29.957}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 46.9, 'feels_like': 40.64, 'temp_min': 46.9, 'temp_max': 46.9, 'pressure': 1017, 'humidity': 45, 'sea_level': 1017, 'grnd_level': 864}, 'visibility': 10000, 'wind': {'speed': 3.53, 'deg': 359}, 'clouds': {'all': 0}, 'dt': 1610745235, 'sys': {'country': 'IN', 'sunrise': 1610761045, 'sunset': 1610798634}, 'timezone': 19800, 'id': 1277907, 'name': 'Salani', 'cod': 200}
# Processing Record 5 of Set 16 | rendsburg
# {'coord': {'lon': 9.6667, 'lat': 54.3}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 29.17, 'feels_like': 20.32, 'temp_min': 28.4, 'temp_max': 30, 'pressure': 1028, 'humidity': 69}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 280}, 'clouds': {'all': 75}, 'dt': 1610745235, 'sys': {'type': 1, 'id': 1846, 'country': 'DE', 'sunrise': 1610695994, 'sunset': 1610724473}, 'timezone': 3600, 'id': 2848245, 'name': 'Rendsburg', 'cod': 200}
# Processing Record 6 of Set 16 | ponta delgada
# {'coord': {'lon': -25.6667, 'lat': 37.7333}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 60.91, 'feels_like': 53.49, 'temp_min': 60.8, 'temp_max': 61, 'pressure': 1026, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 17.27, 'deg': 200}, 'rain': {'1h': 0.1}, 'clouds': {'all': 40}, 'dt': 1610745235, 'sys': {'type': 1, 'id': 6899, 'country': 'PT', 'sunrise': 1610700996, 'sunset': 1610736434}, 'timezone': -3600, 'id': 3372783, 'name': 'Ponta Delgada', 'cod': 200}
# Processing Record 7 of Set 16 | kristiansund
# {'coord': {'lon': 7.732, 'lat': 63.1115}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 23, 'feels_like': 15.71, 'temp_min': 23, 'temp_max': 23, 'pressure': 1026, 'humidity': 74}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 80}, 'clouds': {'all': 0}, 'dt': 1610745235, 'sys': {'type': 1, 'id': 1636, 'country': 'NO', 'sunrise': 1610700273, 'sunset': 1610721122}, 'timezone': 3600, 'id': 6453331, 'name': 'Kristiansund', 'cod': 200}
# Processing Record 8 of Set 16 | uray
# {'coord': {'lon': 64.7758, 'lat': 60.1247}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 3.36, 'feels_like': -5.49, 'temp_min': 3.36, 'temp_max': 3.36, 'pressure': 1015, 'humidity': 94, 'sea_level': 1015, 'grnd_level': 1007}, 'visibility': 6366, 'wind': {'speed': 4.7, 'deg': 210}, 'clouds': {'all': 100}, 'dt': 1610745235, 'sys': {'country': 'RU', 'sunrise': 1610771279, 'sunset': 1610795571}, 'timezone': 18000, 'id': 1488429, 'name': 'Uray', 'cod': 200}
# Processing Record 9 of Set 16 | kamaishi
# {'coord': {'lon': 141.8833, 'lat': 39.2667}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 44.8, 'feels_like': 33.04, 'temp_min': 44.8, 'temp_max': 44.8, 'pressure': 1009, 'humidity': 79, 'sea_level': 1009, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 16.49, 'deg': 221}, 'clouds': {'all': 38}, 'dt': 1610745235, 'sys': {'country': 'JP', 'sunrise': 1610747408, 'sunset': 1610782421}, 'timezone': 32400, 'id': 2112444, 'name': 'Kamaishi', 'cod': 200}
# Processing Record 10 of Set 16 | shirgaon
# {'coord': {'lon': 72.7, 'lat': 19.7}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 72.73, 'feels_like': 70.92, 'temp_min': 72.73, 'temp_max': 72.73, 'pressure': 1010, 'humidity': 58, 'sea_level': 1010, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 7.2, 'deg': 349}, 'clouds': {'all': 84}, 'dt': 1610745235, 'sys': {'country': 'IN', 'sunrise': 1610761584, 'sunset': 1610801462}, 'timezone': 19800, 'id': 1256486, 'name': 'Shirgaon', 'cod': 200}
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                      City      Lat       Lng Current Description  Max Temp  \
# 0          Ribeira Grande  38.5167  -28.7000    scattered clouds     62.60
# 1                  Castro -24.7911  -50.0119    scattered clouds     70.29
# 2                Bac Lieu   9.2850  105.7244          few clouds     72.81
# 3                  Avarua -21.2078 -159.7750    scattered clouds     84.20
# 4                   Tabas  33.5959   56.9244           clear sky     37.40
# 5          Port Elizabeth -33.9180   25.5701    scattered clouds     71.60
# 6  Santa Cruz De La Palma  28.6835  -17.7642       broken clouds     64.40
# 7               Tuatapere -46.1333  167.6833          few clouds     62.53
# 8            Punta Arenas -53.1500  -70.9167           clear sky     55.40
# 9                 Qaanaaq  77.4840  -69.3632     overcast clouds      9.32
#
#    Humidity  Cloudiness  Wind Speed Country
# 0        88          40       13.80      PT
# 1        91          46        7.31      BR
# 2        86          13       10.87      VN
# 3        74          41       10.36      CK
# 4        17           0        4.61      IR
# 5        73          40       24.16      ZA
# 6        52          75        8.05      ES
# 7        60          12        3.76      NZ
# 8        76           0       17.27      CL
# 9        92          98        1.30      GL

# %%
# Change order of columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
df = city_data_df[new_column_order]
df.head(10)
# Out:
#                      City Country      Lat       Lng  Max Temp  Humidity  \
# 0          Ribeira Grande      PT  38.5167  -28.7000     62.60        88
# 1                  Castro      BR -24.7911  -50.0119     70.29        91
# 2                Bac Lieu      VN   9.2850  105.7244     72.81        86
# 3                  Avarua      CK -21.2078 -159.7750     84.20        74
# 4                   Tabas      IR  33.5959   56.9244     37.40        17
# 5          Port Elizabeth      ZA -33.9180   25.5701     71.60        73
# 6  Santa Cruz De La Palma      ES  28.6835  -17.7642     64.40        52
# 7               Tuatapere      NZ -46.1333  167.6833     62.53        60
# 8            Punta Arenas      CL -53.1500  -70.9167     55.40        76
# 9                 Qaanaaq      GL  77.4840  -69.3632      9.32        92
#
#    Cloudiness  Wind Speed Current Description
# 0          40       13.80    scattered clouds
# 1          46        7.31    scattered clouds
# 2          13       10.87          few clouds
# 3          41       10.36    scattered clouds
# 4           0        4.61           clear sky
# 5          40       24.16    scattered clouds
# 6          75        8.05       broken clouds
# 7          12        3.76          few clouds
# 8           0       17.27           clear sky
# 9          98        1.30     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
df.to_csv(output_data_file, index_label="City_ID")
